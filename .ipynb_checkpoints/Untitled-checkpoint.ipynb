# %%
# !pip install tabula-py
# Out:
# ...
#     100% |████████████████████████████████| 10.4MB 307kB/s ta 0:00:01   65% |████████████████████▉           | 6.8MB 168kB/s eta 0:00:22
# ...
#     100% |████████████████████████████████| 10.2MB 623kB/s ta 0:00:01  4% |█▌                              | 460kB 91kB/s eta 0:01:47
# ...
#   Found existing installation: pandas 0.23.4
#     Uninstalling pandas-0.23.4:
#       Successfully uninstalled pandas-0.23.4
# ...
# You are using pip version 18.0, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import requests
from tabula import read_pdf
import urllib.request

# %%
url = 'https://www.mohfw.gov.in/pdf/DistrictWiseList324.pdf'
urllib.request.urlretrieve(url, 'districtdata.pdf')
# Out:
# ('districtdata.pdf', <http.client.HTTPMessage at 0x10859de80>)

# %%
df = read_pdf('districtdata.pdf',pages='all',stream=True)
# Out:
# Got stderr: Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 9.0.1
# Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Apr 04, 2020 6:18:41 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
df
# Out:
# [{'extraction_method': 'lattice',
#   'top': 53.54516,
#   'left': 92.92665,
#   'width': 422.49249267578125,
#   'height': 681.5584716796875,
#   'right': 515.4191,
#   'bottom': 735.10364,
#   'data': [[{'top': 53.54516,
#      'left': 92.92665,
#      'width': 421.15728759765625,
#      'height': 19.24786376953125,
#      'text': 'State/District wise details of Positive cases of Covid19'},
#     {'top': 53.54516,
#      'left': 514.0839,
#      'width': 1.335205078125,
#      'height': 19.24786376953125,
#      'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''},
#     {'top': 0.0, 'left': 0.0, 'width': 0.0, 'height': 0.0, 'text': ''}],
#    [{'top': 72.79302,
#      'left': 92.92665,
#      'width': 98.54232788085938,
# ...
